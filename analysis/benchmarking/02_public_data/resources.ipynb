# %%
library(tidyverse)
library(ggplot2)
library(lubridate)
# Out:
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
sessionInfo()
# Out:
# R version 4.2.1 (2022-06-23)
# Platform: x86_64-apple-darwin13.4.0 (64-bit)
# Running under: macOS Big Sur ... 10.16
#
# Matrix products: default
# BLAS/LAPACK: /Users/joonklaps/opt/anaconda3/lib/libopenblasp-r0.3.20.dylib
#
# locale:
# [1] en_GB.UTF-8/en_GB.UTF-8/en_GB.UTF-8/C/en_GB.UTF-8/en_GB.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] lubridate_1.9.3 forcats_1.0.0   stringr_1.5.1   dplyr_1.1.4
#  [5] purrr_1.0.2     readr_2.1.5     tidyr_1.3.1     tibble_3.2.1
#  [9] ggplot2_3.5.2   tidyverse_2.0.0
#
# loaded via a namespace (and not attached):
#  [1] pillar_1.10.2      compiler_4.2.1     RColorBrewer_1.1-3 base64enc_0.1-3
#  [5] tools_4.2.1        digest_0.6.36      uuid_1.2-0         timechange_0.3.0
#  [9] jsonlite_1.8.8     evaluate_1.0.3     lifecycle_1.0.4    gtable_0.3.6
# [13] pkgconfig_2.0.3    rlang_1.1.4        IRdisplay_1.1      cli_3.6.3
# [17] IRkernel_1.3.2     fastmap_1.2.0      repr_1.1.7         withr_3.0.2
# [21] generics_0.1.4     vctrs_0.6.5        hms_1.1.3          grid_4.2.1
# [25] tidyselect_1.2.1   glue_1.7.0         R6_2.6.1           pbdZMQ_0.3-9
# [29] farver_2.1.2       tzdb_0.4.0         magrittr_2.0.3     scales_1.4.0
# [33] htmltools_0.5.8.1  stringi_1.8.4      crayon_1.5.3

# %%
trace_file <- read.csv("./human-virus/pipeline_info/execution_trace_2025-06-08_21-30-08.txt", sep="\t", na.strings = c("NA", "N/A", "null", "-",""))

# %%
convb <- function(x){
  ptn <- "(\\d*(.\\d+)*) (.*)"
  num  <- as.numeric(sub(ptn, "\\1", x))
  unit <- sub(ptn, "\\3", x)
  unit[unit==""] <- "1"

  mult <- c("1"=1, "KB"=1024, "MB"=1024^2, "GB"=1024^3)
  num * unname(mult[unit])
}

# %%
# Vectorized function to convert time strings to milliseconds
time_to_ms <- function(time_str) {
  # Handle different input formats
  time_str <- as.character(time_str)

  # Initialize total milliseconds vector
  total_ms <- rep(0, length(time_str))

  # Parse different time components using vectorized operations
  # Handle hours (e.g., "1h", "2.5h")
  hour_match <- grepl("\\d+(\\.\\d+)?h", time_str)
  if (any(hour_match)) {
    hours <- as.numeric(gsub(".*?(\\d+(?:\\.\\d+)?)h.*", "\\1", time_str[hour_match]))
    total_ms[hour_match] <- total_ms[hour_match] + (hours * 60 * 60 * 1000)
  }

  # Handle minutes (e.g., "30m", "20.5m")
  minute_match <- grepl("\\d+(\\.\\d+)?m", time_str)
  if (any(minute_match)) {
    minutes <- as.numeric(gsub(".*?(\\d+(?:\\.\\d+)?)m.*", "\\1", time_str[minute_match]))
    total_ms[minute_match] <- total_ms[minute_match] + (minutes * 60 * 1000)
  }

  # Handle seconds (e.g., "30s", "34.8s")
  second_match <- grepl("\\d+(\\.\\d+)?s", time_str)
  if (any(second_match)) {
    seconds <- as.numeric(gsub(".*?(\\d+(?:\\.\\d+)?)s.*", "\\1", time_str[second_match]))
    total_ms[second_match] <- total_ms[second_match] + (seconds * 1000)
  }

  # Handle milliseconds (e.g., "500ms", "0ms")
  ms_match <- grepl("\\d+(\\.\\d+)?ms", time_str)
  if (any(ms_match)) {
    ms <- as.numeric(gsub(".*?(\\d+(?:\\.\\d+)?)ms.*", "\\1", time_str[ms_match]))
    total_ms[ms_match] <- total_ms[ms_match] + ms
  }

  # Handle plain numbers (assume seconds)
  plain_number_match <- grepl("^\\d+(\\.\\d+)?$", time_str)
  if (any(plain_number_match)) {
    seconds <- as.numeric(time_str[plain_number_match])
    total_ms[plain_number_match] <- total_ms[plain_number_match] + (seconds * 1000)
  }

  return(total_ms)
}

# Vectorized function to convert milliseconds back to readable time string
ms_to_time <- function(ms) {
  # Vectorized version
  result <- character(length(ms))

  for (i in seq_along(ms)) {
    if (ms[i] < 1000) {
      result[i] <- paste0(ms[i], "ms")
    } else {
      # Convert to seconds, minutes, hours
      total_seconds <- ms[i] / 1000
      hours <- floor(total_seconds / 3600)
      minutes <- floor((total_seconds %% 3600) / 60)
      seconds <- total_seconds %% 60

      # Build time string
      time_parts <- c()

      if (hours > 0) {
        time_parts <- c(time_parts, paste0(hours, "h"))
      }

      if (minutes > 0) {
        time_parts <- c(time_parts, paste0(minutes, "m"))
      }

      if (seconds > 0) {
        if (seconds == floor(seconds)) {
          time_parts <- c(time_parts, paste0(seconds, "s"))
        } else {
          time_parts <- c(time_parts, paste0(round(seconds, 1), "s"))
        }
      }

      if (length(time_parts) == 0) {
        result[i] <- "0ms"
      } else {
        result[i] <- paste(time_parts, collapse = " ")
      }
    }
  }

  return(result)
}

# %%
# Kaiju for reads failed multiple times and skewed the results
result <- trace_file %>% filter(!grepl("FASTQ_KRAKEN_KAIJU", name)) %>%
  summarise(
    sum_cpu_time = ms_to_time(sum(time_to_ms(duration),na.rm = TRUE)),
    sum_real_time = ms_to_time(sum(time_to_ms(realtime),na.rm = TRUE)),
    peak_ram = utils:::format.object_size(max(convb(peak_rss), na.rm = TRUE), "auto"),
    peak_vmem = utils:::format.object_size(max(convb(peak_vmem),na.rm = TRUE), "auto")
  )
result
# Out:
#   sum_cpu_time   sum_real_time  peak_ram peak_vmem
# 1 411h 53m 21.5s 382h 56m 53.1s 79.2 Gb  85.3 Gb

# %%
trace_file %>% filter(!grepl("KAIJU|NOCOV", name)) %>%
    arrange(desc(convb(peak_rss)))
# Out:
#      task_id hash      native_id
# 1    3900    77/6f0430 64604532_23
# 2    4185    a9/7c775e 64604539_13
# 3    7259    ce/e496e5 64607746_26
# 4    7339    a7/492e7d 64607927_1
# 5    5542    73/30438a 64605934_1
# 6    5538    e4/da3d96 64605911_27
# 7    3182    b7/de0022 64603324_25
# 8    7310    22/084906 64607927_0
# 9    3316    5e/dd05c5 64603515_25
# 10   3901    30/1ca0f0 64604532_25
# 11   5125    f3/71e35a 64605496_15
# 12   5540    ad/bc8e95 64605911_29
# 13   5131    fa/f0593e 64605496_19
# 14   5275    f7/f37ed8 64605682_15
# 15   6836    a4/36f0cf 64607331_26
# 16   6963    68/e6c01b 64607545_18
# 17   6997    9a/619f0e 64607546_0
# 18   3297    d0/426a61 64603515_12
# 19   3899    89/e6c1fb 64604532_24
# 20   5260    ee/8ab71e 64605682_6
# 21   5535    3b/e9d12a 64605911_24
# 22   7100    48/92118f 64607701_22
# 23   4128    bf/bbdedf 64604380_16
# 24   6811    a9/ae9aec 64607331_7
# 25   7002    fc/f4e792 64607546_2
# 26   3337    a0/4f14ce 64603536_19
# 27   3905    84/97b531 64604532_27
# 28    681    a3/be2972 64587259_21
# 29   4121    48/d210da 64604380_12
# 30   5368    c2/8f02dd 64605761_29
# ⋮    ⋮       ⋮         ⋮
# 8051 8239    f1/e2a7d0 64608824_1
# 8052 8226    5b/a1fd6b 64608824_2
# 8053 8232    95/36b9ba 64608824_4
# 8054 8240    29/e3f4bb 64608824_6
# 8055 8225    0d/aa3e6b 64608824_9
# 8056 8237    e6/204c80 64608824_10
# 8057 8242    04/65b8e0 64608824_11
# 8058 8243    3b/682c00 64608824_12
# 8059 8241    16/2481a1 64608824_13
# 8060 8245    3a/916f68 64608824_15
# 8061 8246    a0/bd5438 64608824_17
# 8062 8248    71/8884b3 64608824_18
# 8063 8247    46/724fba 64608824_19
# 8064 8233    8b/817266 64608824_3
# 8065 8238    e0/7bf43b 64608824_5
# 8066 8236    16/9578b0 64608824_8
# 8067 8228    5a/0e7ce1 64608824_14
# 8068 8244    75/bff539 64608824_16
# 8069 8235    7b/296e9b 64608824_7
# 8070 8251    54/d91d9b 64608824_20
# 8071 8259    2a/911921 64608824_21
# 8072 8253    51/99774f 64608824_22
# 8073 8252    8f/fdf02b 64608824_23
# 8074 8255    e8/211e07 64608824_24
# 8075 8254    8c/b3e64c 64608824_25
# 8076 8258    a6/48a5b9 64608824_26
# 8077 8249    17/2ab7ec 64608824_27
# 8078 8257    5e/4fa144 64608824_28
# 8079 8256    48/dd029f 64608824_29
# 8080 6941    29/041654 64608328_27
#      name
# 1    NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX16990730_cl10)
# 2    NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX16990730_cl9)
# 3    NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_MAP_CONSENSUS:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX16990730_cl10)
# 4    NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_MAP_CONSENSUS:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX16990730_cl9)
# 5    NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_2:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX16990730_cl9)
# 6    NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_2:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX16990730_cl10)
# 7    NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:MAP_READS:BWAMEM2_MEM (SRX23148725_cl35)
# 8    NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_MAP_CONSENSUS:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX28439211_cl9)
# 9    NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:MAP_READS:BWAMEM2_MEM (SRX23148725_cl76)
# 10   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX28439211_cl9)
# 11   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_2:MAP_READS:BWAMEM2_MEM (SRX1617782_cl85)
# 12   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_2:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX28439211_cl9)
# 13   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_2:MAP_READS:BWAMEM2_MEM (SRX23148725_cl35)
# 14   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_2:MAP_READS:BWAMEM2_MEM (SRX23148725_cl76)
# 15   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_MAP_CONSENSUS:MAP_READS:BWAMEM2_MEM (SRX23148725_cl35)
# 16   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_MAP_CONSENSUS:MAP_READS:BWAMEM2_MEM (SRX23148725_cl28)
# 17   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_MAP_CONSENSUS:MAP_READS:BWAMEM2_MEM (SRX23148725_cl76)
# 18   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:MAP_READS:BWAMEM2_MEM (SRX23148725_cl28)
# 19   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX27284000_cl3)
# 20   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_2:MAP_READS:BWAMEM2_MEM (SRX23148725_cl28)
# 21   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_2:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX27284000_cl3)
# 22   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_MAP_CONSENSUS:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX27284000_cl3)
# 23   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:MAP_READS:BWAMEM2_MEM (SRX16990730_cl9)
# 24   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_MAP_CONSENSUS:MAP_READS:BWAMEM2_MEM (SRX1617782_cl85)
# 25   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_MAP_CONSENSUS:MAP_READS:BWAMEM2_MEM (SRX16990730_cl9)
# 26   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX23148725_cl35)
# 27   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX23148725_cl76)
# 28   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_ASSEMBLY:EXTEND_SPADES:MAP_READS_CONTIGS:BWAMEM2_MEM (SRX1617782)
# 29   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_1:MAP_READS:BWAMEM2_MEM (SRX1617782_cl2)
# 30   NFCORE_VIRALGENIE:VIRALGENIE:FASTQ_FASTA_ITERATIVE_CONSENSUS:ITERATION_2:BAM_DEDUPLICATE:PICARD_MARKDUPLICATES (SRX23148725_cl35)
# ⋮    ⋮
# 8051 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX21588694_cl8)
# 8052 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX18766849_cl8)
# 8053 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX20230124_cl89)
# 8054 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX21588694_cl9)
# 8055 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX18766827_cl40)
# 8056 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX21588694_cl6)
# 8057 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX23148725_cl35)
# 8058 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX23148725_cl76)
# 8059 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX23148725_cl28)
# 8060 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX24583791_cl1)
# 8061 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX24653055_cl0)
# 8062 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX26211983_cl11)
# 8063 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX24653055_cl1)
# 8064 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX21588694_cl1)
# 8065 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX21588694_cl7)
# 8066 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX21588694_cl5)
# 8067 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX19467387_cl10)
# 8068 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX24583791_cl0)
# 8069 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX21588694_cl4)
# 8070 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX26211983_cl7)
# 8071 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX27315411_cl1)
# 8072 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX27181532_cl3)
# 8073 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX27181532_cl2)
# 8074 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX27181532_cl8)
# 8075 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX27181532_cl6)
# 8076 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX27315411_cl0)
# 8077 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX26211983_cl17)
# 8078 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX27284000_cl3)
# 8079 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:CHECKV_ENDTOEND (SRX27284000_cl11)
# 8080 NFCORE_VIRALGENIE:VIRALGENIE:CONSENSUS_QC:QUAST_QC (SRX12412076_cl0)
#      status    exit submit                  duration  realtime X.cpu   peak_rss
# 1    COMPLETED 0    2025-06-09 02:44:27.231 3m 5s     1m 2s    143.1%  17.1 GB
# 2    COMPLETED 0    2025-06-09 02:44:57.220 4m 10s    1m 13s   137.2%  17.1 GB
# 3    COMPLETED 0    2025-06-09 04:14:42.485 2m        1m 25s   125.9%  17 GB
# 4    COMPLETED 0    2025-06-09 04:16:27.750 1m 29s    1m 18s   131.4%  17 GB
# 5    COMPLETED 0    2025-06-09 03:22:12.706 2m 14s    1m 30s   126.0%  16.9 GB
# 6    COMPLETED 0    2025-06-09 03:21:32.456 2m 55s    1m 17s   123.9%  16.9 GB
# 7    COMPLETED 0    2025-06-08 23:55:31.967 5m 10s    2m 18s   722.1%  16.4 GB
# 8    COMPLETED 0    2025-06-09 04:16:27.750 2m 19s    2m 8s    100.0%  15.7 GB
# 9    COMPLETED 0    2025-06-09 00:09:29.154 1h 5m 48s 2m 10s   670.1%  15.6 GB
# 10   COMPLETED 0    2025-06-09 02:44:27.231 4m 15s    1m 53s   112.3%  15.6 GB
# 11   COMPLETED 0    2025-06-09 03:01:42.264 3m 20s    1m 6s    671.3%  15.6 GB
# 12   COMPLETED 0    2025-06-09 03:21:32.456 3m 45s    1m 54s   111.8%  15.6 GB
# 13   COMPLETED 0    2025-06-09 03:01:42.264 4m 25s    2m 8s    756.6%  15.5 GB
# 14   COMPLETED 0    2025-06-09 03:06:07.644 14m 14s   2m 20s   627.3%  15.5 GB
# 15   COMPLETED 0    2025-06-09 04:03:17.397 9m 5s     2m 10s   667.5%  15.5 GB
# 16   COMPLETED 0    2025-06-09 04:10:27.456 3m 15s    2m 7s    683.6%  15.4 GB
# 17   COMPLETED 0    2025-06-09 04:10:37.359 3m 20s    2m 20s   664.0%  15.4 GB
# 18   COMPLETED 0    2025-06-09 00:09:29.154 57m 48s   2m 13s   639.4%  15.1 GB
# 19   COMPLETED 0    2025-06-09 02:44:27.231 3m        59s      132.4%  15 GB
# 20   COMPLETED 0    2025-06-09 03:06:07.644 2m 54s    2m 16s   743.9%  15 GB
# 21   COMPLETED 0    2025-06-09 03:21:32.456 2m 45s    1m 8s    118.4%  14.8 GB
# 22   COMPLETED 0    2025-06-09 04:13:02.419 1m 25s    1m 7s    119.5%  14.8 GB
# 23   COMPLETED 0    2025-06-09 01:48:07.039 55m 35s   1m 21s   983.0%  14.7 GB
# 24   COMPLETED 0    2025-06-09 04:03:17.396 7m 5s     1m 4s    628.5%  14.7 GB
# 25   COMPLETED 0    2025-06-09 04:10:37.359 2m 25s    1m 16s   940.7%  14.4 GB
# 26   COMPLETED 0    2025-06-09 00:13:47.198 11m 54s   4m 7s    103.6%  14.1 GB
# 27   COMPLETED 0    2025-06-09 02:44:27.231 6m 30s    4m 14s   102.4%  14.1 GB
# 28   CACHED    0    2025-06-05 00:31:14.564 5m 30s    54s      1010.2% 14 GB
# 29   COMPLETED 0    2025-06-09 01:48:07.039 45m 45s   1m 11s   624.2%  14 GB
# 30   COMPLETED 0    2025-06-09 03:11:07.327 13m 25s   4m 27s   89.9%   14 GB
# ⋮    ⋮         ⋮    ⋮                       ⋮         ⋮        ⋮       ⋮
# 8051 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8052 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8053 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8054 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8055 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8056 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8057 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8058 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8059 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8060 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8061 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8062 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8063 FAILED     1   2025-06-09 04:35:23.528 58.6s     5s       NA      NA
# 8064 FAILED     1   2025-06-09 04:35:23.528 1m 4s     10s      NA      NA
# 8065 FAILED     1   2025-06-09 04:35:23.528 1m 4s     10s      NA      NA
# 8066 FAILED     1   2025-06-09 04:35:23.528 1m 4s     10s      NA      NA
# 8067 FAILED     1   2025-06-09 04:35:23.528 1m 4s     10s      NA      NA
# 8068 FAILED     1   2025-06-09 04:35:23.528 1m 4s     10s      NA      NA
# 8069 FAILED     1   2025-06-09 04:35:23.528 1m 9s     15s      NA      NA
# 8070 FAILED     1   2025-06-09 04:35:23.528 1m 9s     5s       NA      NA
# 8071 FAILED     1   2025-06-09 04:35:23.528 1m 9s     5s       NA      NA
# 8072 FAILED     1   2025-06-09 04:35:23.528 1m 14s    5s       NA      NA
# 8073 FAILED     1   2025-06-09 04:35:23.528 1m 19s    5s       NA      NA
# 8074 FAILED     1   2025-06-09 04:35:23.528 1m 24s    5s       NA      NA
# 8075 FAILED     1   2025-06-09 04:35:23.528 1m 29s    5s       NA      NA
# 8076 FAILED     1   2025-06-09 04:35:23.528 1m 29s    3ms      NA      NA
# 8077 FAILED     1   2025-06-09 04:35:23.528 1m 39s    5s       NA      NA
# 8078 FAILED     1   2025-06-09 04:35:23.528 1m 39s    5s       NA      NA
# 8079 FAILED     1   2025-06-09 04:35:23.528 1m 44s    5s       NA      NA
# 8080 FAILED    NA   2025-06-09 04:25:27.794 14m 19s   12m 35s  NA      NA
#      peak_vmem rchar    wchar
# 1    33.6 GB   847.4 MB 61 MB
# 2    33.6 GB   929.3 MB 92.3 MB
# 3    33.1 GB   845.4 MB 60.1 MB
# 4    33.5 GB   924.4 MB 91.6 MB
# 5    32.8 GB   925.9 MB 91.7 MB
# 6    32.8 GB   847.6 MB 61 MB
# 7    49.4 GB   14.9 GB  14.3 GB
# 8    33.6 GB   853.8 MB 477.1 MB
# 9    59.7 GB   14.7 GB  14.2 GB
# 10   32.8 GB   851.7 MB 476.6 MB
# 11   27.8 GB   7.5 GB   7.2 GB
# 12   32.8 GB   853.8 MB 477.1 MB
# 13   54.3 GB   15 GB    14.4 GB
# 14   69.8 GB   14.7 GB  14.2 GB
# 15   63.7 GB   15 GB    14.4 GB
# 16   75 GB     14.8 GB  14.2 GB
# 17   67.7 GB   14.7 GB  14.2 GB
# 18   75.1 GB   14.8 GB  14.2 GB
# 19   33.6 GB   481 MB   264.9 MB
# 20   74.2 GB   14.8 GB  14.2 GB
# 21   32.8 GB   484.8 MB 265.4 MB
# 22   32.8 GB   484.8 MB 265.4 MB
# 23   54.1 GB   8.8 GB   8.2 GB
# 24   27.3 GB   7.5 GB   7.2 GB
# 25   58.8 GB   9.1 GB   8.5 GB
# 26   32.7 GB   1.3 GB   1.3 GB
# 27   32.8 GB   1.3 GB   1.4 GB
# 28   39.9 GB   3.1 GB   3.1 GB
# 29   32.6 GB   7.4 GB   7.2 GB
# 30   33.6 GB   1.3 GB   1.3 GB
# ⋮    ⋮         ⋮        ⋮
# 8051 NA        NA       NA
# 8052 NA        NA       NA
# 8053 NA        NA       NA
# 8054 NA        NA       NA
# 8055 NA        NA       NA
# 8056 NA        NA       NA
# 8057 NA        NA       NA
# 8058 NA        NA       NA
# 8059 NA        NA       NA
# 8060 NA        NA       NA
# 8061 NA        NA       NA
# 8062 NA        NA       NA
# 8063 NA        NA       NA
# 8064 NA        NA       NA
# 8065 NA        NA       NA
# 8066 NA        NA       NA
# 8067 NA        NA       NA
# 8068 NA        NA       NA
# 8069 NA        NA       NA
# 8070 NA        NA       NA
# 8071 NA        NA       NA
# 8072 NA        NA       NA
# 8073 NA        NA       NA
# 8074 NA        NA       NA
# 8075 NA        NA       NA
# 8076 NA        NA       NA
# 8077 NA        NA       NA
# 8078 NA        NA       NA
# 8079 NA        NA       NA
# 8080 NA        NA       NA
